# %% [markdown]
# # Intent Classifier Notebook

# %% [markdown]
# ## Import Library

# %%
import pandas as pd
import numpy as np
import random
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
import torch
from torch.utils.data import Dataset, DataLoader
from transformers import BertTokenizer, BertForSequenceClassification, get_scheduler
from torch.optim import AdamW
import pandas as pd
import os
from sklearn.preprocessing import LabelEncoder
from glob import glob
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
import torch
from transformers import DataCollatorWithPadding
from datasets import Dataset as HFDataset
from tqdm import tqdm
from transformers import AutoTokenizer, AutoModelForSequenceClassification
from torch.cuda.amp import autocast, GradScaler

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## Load Dataset

# %%
folder_path = "../dataset/intent_dataset_2/"

all_data = []

for filename in os.listdir(folder_path):
    file_path = os.path.join(folder_path, filename)

    if filename.endswith(".csv"):
        with open(file_path, "r", encoding="utf-8") as f:
            for line in f:
                line = line.strip()
                if not line or "," not in line:
                    continue 

                intent, text = line.split(",", 1)
                all_data.append({"label": intent.strip(), "text": text.strip()})

df = pd.DataFrame(all_data)

print(df.head())

print("\nJumlah data per intent:")
intent_counts = df['label'].value_counts().sort_index() 
for intent, count in intent_counts.items():
    print(f"- {intent}: {count} data")

print(f"\nTotal intent unik: {df['label'].nunique()}")
# Out:
#                     label                                               text
# 0  ask_first_aid_solution  Apa yang harus saya lakukan jika mesin mobil s...
# 1  ask_first_aid_solution  Gimana cara ngatasin mesin mobil yang susah ny...
# 2  ask_first_aid_solution  Langkah awal apa yang bisa saya ambil kalo mes...
# 3  ask_first_aid_solution  Apa yang harus saya cek dulu kalo motor saya s...
# 4  ask_first_aid_solution  Bagaimana cara mengatasi motor yang sulit dihi...
#
# Jumlah data per intent:
# - ask_first_aid_solution: 525 data
# - ask_possible_cause: 1110 data
# - casual_greeting: 1236 data
# - fallback: 540 data
# - goodbye: 1364 data
# - report_noise_or_smell: 347 data
#
# Total intent unik: 6

# %% [markdown]
# ## Pre Process Data

# %% [markdown]
# ### Data Augmentation

# %%
tokenizer = AutoTokenizer.from_pretrained("Wikidepia/IndoT5-base-paraphrase")
model = AutoModelForSeq2SeqLM.from_pretrained("Wikidepia/IndoT5-base-paraphrase")
model = model.to(device)
model.eval()
# Out:
# T5ForConditionalGeneration(
#   (shared): Embedding(32128, 768)
#   (encoder): T5Stack(
#     (embed_tokens): Embedding(32128, 768)
#     (block): ModuleList(
#       (0): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#               (relative_attention_bias): Embedding(32, 12)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseGatedActDense(
#               (wi_0): Linear(in_features=768, out_features=2048, bias=False)
# ...

# %%
def batch_paraphrase(text_list, max_length=256, num_return_sequences=1, num_beams=5):
    encodings = tokenizer(
        text_list,
        return_tensors="pt",
        padding=True,
        truncation=True,
        max_length=512
    ).to(device)

    with torch.no_grad():
        outputs = model.generate(
            input_ids=encodings["input_ids"],
            attention_mask=encodings["attention_mask"],
            max_length=max_length,
            num_beams=num_beams,
            num_return_sequences=num_return_sequences,
            no_repeat_ngram_size=2,
            early_stopping=True
        )

    results = tokenizer.batch_decode(outputs, skip_special_tokens=True)
    return results

# %%
# Target jumlah data per label = jumlah data label terbanyak
max_count = df['label'].value_counts().max()

# Pisahkan data berdasarkan label
label_groups = df.groupby('label')

augmented_rows = []

for label, group in tqdm(label_groups, desc="Processing labels"):
    current_count = len(group)
    needed = max_count - current_count

    if needed <= 0:
        continue  # Skip jika sudah cukup

    texts_to_augment = group['text'].tolist()
    times_to_augment = (needed // len(texts_to_augment)) + 1

    # Gandakan teks sesuai kebutuhan
    augmented_texts = (texts_to_augment * times_to_augment)[:needed]
    
    batch_size = 16
    num_return_sequences = 1  # Bisa lebih jika ingin variasi tambahan

    for i in range(0, len(augmented_texts), batch_size):
        batch_texts = augmented_texts[i:i+batch_size]

        augmented = batch_paraphrase(
            batch_texts,
            num_return_sequences=num_return_sequences
        )

        for text in augmented:
            augmented_rows.append({
                "text": text,
                "label": label
            })

# Gabungkan dengan data asli
df_augmented = pd.DataFrame(augmented_rows)
df_balanced = pd.concat([df, df_augmented]).reset_index(drop=True)

# Konfirmasi distribusi baru
print("\nDistribusi data setelah augmentasi:")
print(df_balanced['label'].value_counts())
# Out:
# Processing labels: 100%|██████████| 6/6 [23:30<00:00, 235.08s/it]
# Distribusi data setelah augmentasi:
# ask_first_aid_solution    1364
# ask_possible_cause        1364
# casual_greeting           1364
# fallback                  1364
# goodbye                   1364
# report_noise_or_smell     1364
# Name: label, dtype: int64

# %% [markdown]
# ### Label Encoding

# %%
le = LabelEncoder()
df_balanced["label_id"] = le.fit_transform(df_balanced["label"])
label2id = {str(label): int(id_) for label, id_ in zip(le.classes_, le.transform(le.classes_))}
id2label = {int(id_): str(label) for id_, label in zip(le.transform(le.classes_), le.classes_)}

# %% [markdown]
# ### Indobert Tokenization

# %%
tokenizer = BertTokenizer.from_pretrained("indobenchmark/indobert-base-p1")
dataset = HFDataset.from_pandas(df_balanced[['text', 'label_id']])


def tokenize_function(examples):
    return tokenizer(
        examples["text"],
        truncation=True,
        padding=False
    )

tokenized_dataset = dataset.map(tokenize_function, batched=True)
tokenized_dataset = tokenized_dataset.rename_column("label_id", "labels")
tokenized_dataset = tokenized_dataset.remove_columns(["text"])
# Out:
# ...
# Map: 100%|██████████| 8184/8184 [00:04<00:00, 1788.58 examples/s]

# %%
data_collator = DataCollatorWithPadding(tokenizer=tokenizer, return_tensors="pt")

train_test = tokenized_dataset.train_test_split(test_size=0.2)
train_loader = DataLoader(train_test['train'], shuffle=True, batch_size=16, collate_fn=data_collator, pin_memory=True, num_workers=4)
val_loader = DataLoader(train_test['test'], batch_size=16, collate_fn=data_collator)

# %%
model = BertForSequenceClassification.from_pretrained(
    "indobenchmark/indobert-base-p1",
    num_labels=len(label2id),
    id2label=id2label,
    label2id=label2id
).to(device)
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at indobenchmark/indobert-base-p1 and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
optimizer = AdamW(model.parameters(), lr=5e-5)
num_epochs = 100
num_training_steps = num_epochs * len(train_loader)
lr_scheduler = get_scheduler(
    "linear", optimizer=optimizer,
    num_warmup_steps=0,
    num_training_steps=num_training_steps
)

# %%
best_val_loss = float('inf')
patience = 3
counter = 0
scaler = GradScaler()

for epoch in range(num_epochs):
    model.train()
    train_loss = 0.0
    loop = tqdm(train_loader, leave=True)

    for batch in loop:
        batch = {k: v.to(device) for k, v in batch.items()}
        with autocast():
            outputs = model(**batch)
            loss = outputs.loss

        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()
        optimizer.zero_grad()
        lr_scheduler.step()

        train_loss += loss.item()
        loop.set_description(f"Epoch {epoch+1}")
        loop.set_postfix(loss=loss.item())

    model.eval()
    val_loss = 0.0
    with torch.no_grad():
        for batch in val_loader:
            batch = {k: v.to(device) for k, v in batch.items()}
            with autocast():
                outputs = model(**batch)
                loss = outputs.loss
                val_loss += loss.item()

    val_loss /= len(val_loader)
    print(f"\n[Epoch {epoch+1}] Validation Loss: {val_loss:.4f}")

    # ==== Early Stopping Check ====
    if best_val_loss - val_loss > 1e-5:
        best_val_loss = val_loss
        counter = 0
        torch.save(model.state_dict(), "../generated/best_intent_classifier.pt")
        print(f"New best model saved. Validation Loss improved to {val_loss:.8f}")
    else:
        counter += 1
        print(f"Early Stop Counter: {counter}/{patience}")
        if counter >= patience:
            print("Early stopping triggered.")
            break
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12180\820739414.py:4: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = GradScaler()
# c:\Users\DELL\.conda\envs\python10\lib\site-packages\torch\amp\grad_scaler.py:136: UserWarning: torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.
#   warnings.warn(
#   0%|          | 0/410 [00:00<?, ?it/s]c:\Users\DELL\.conda\envs\python10\lib\site-packages\torch\utils\data\dataloader.py:665: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12180\820739414.py:13: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# ...

# %%
model.eval()
preds, labels = [], []

for batch in val_loader:
    batch = {k: v.to(device) for k, v in batch.items()}
    with torch.no_grad():
        output = model(**batch)
    logits = output.logits
    predictions = torch.argmax(logits, dim=-1)
    preds.extend(predictions.cpu().numpy())
    labels.extend(batch["labels"].cpu().numpy())

print(classification_report(labels, preds, target_names=le.classes_))
# Out:
#                         precision    recall  f1-score   support
#
# ask_first_aid_solution       1.00      1.00      1.00       265
#     ask_possible_cause       1.00      1.00      1.00       295
#        casual_greeting       1.00      1.00      1.00       268
#               fallback       1.00      1.00      1.00       293
#                goodbye       1.00      1.00      1.00       268
#  report_noise_or_smell       1.00      1.00      1.00       248
#
#               accuracy                           1.00      1637
#              macro avg       1.00      1.00      1.00      1637
#           weighted avg       1.00      1.00      1.00      1637

# %%
model.save_pretrained("../generated/intent_classifier_indobert")
tokenizer.save_pretrained("../generated/tokenizer_intent_classifier_indobert")
# Out:
# ('../generated/tokenizer_intent_classifier_indobert\\tokenizer_config.json',
#  '../generated/tokenizer_intent_classifier_indobert\\special_tokens_map.json',
#  '../generated/tokenizer_intent_classifier_indobert\\vocab.txt',
#  '../generated/tokenizer_intent_classifier_indobert\\added_tokens.json')

# %%
tokenizer = AutoTokenizer.from_pretrained("../generated/tokenizer_intent_classifier_indobert")
model_intent = AutoModelForSequenceClassification.from_pretrained("../generated/intent_classifier_indobert")
model_intent.eval()
# Out:
# BertForSequenceClassification(
#   (bert): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(50000, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x BertLayer(
#           (attention): BertAttention(
#             (self): BertSdpaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
# ...

# %%
label_map = {
    0 : "ask_first_aid_solution",
    1 : "ask_possible_cause",
    2 : "casual_greeting",
    3 : "fallback",
    4 : "goodbye",
    5 : "report_noise_or_smell"
}

# %%
test_texts = [
"mobilku mogok di tengah jalan, apa yang harus saya lakukan?",
]

# %%
for text in test_texts:
    inputs = tokenizer(text, return_tensors="pt", truncation=True, padding=True)
    inputs = {k: v for k, v in inputs.items()}
    
    with torch.no_grad():
        outputs = model_intent(**inputs) 
        probs = torch.nn.functional.softmax(outputs.logits, dim=-1)
        pred_label = torch.argmax(probs, dim=-1).item()
        label_name = label_map[pred_label]

    print(f"Text: {text}\nPredicted intent: {label_name}\n{'-'*50}")
# Out:
# Text: mobilku mogok di tengah jalan, apa yang harus saya lakukan?
# Predicted intent: ask_first_aid_solution
# --------------------------------------------------

# %%
model_intent.eval()
model_intent.cpu()

dummy_input = tokenizer("Saya ingin booking servis", return_tensors="pt", padding=True, truncation=True)

torch.onnx.export(
    model_intent,                                              # Trained model
    (input_ids_for_export, attention_mask_for_export),  # Input tuple
    "../generated/intent_classifier.onnx",                           # Output file
    input_names=["input_ids", "attention_mask"],
    output_names=["logits"],
    dynamic_axes={
        'input_ids': {0: 'batch_size', 1: 'sequence'},
        'attention_mask': {0: 'batch_size', 1: 'sequence'},
        'logits': {0: 'batch_size'}
    },
    opset_version=14,                               
    do_constant_folding=True
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 model_intent.eval()
#       2 model_intent.cpu()
#       4 dummy_input = tokenizer("Saya ingin booking servis", return_tensors="pt", padding=True, truncation=True)
#
# NameError: name 'model_intent' is not defined
